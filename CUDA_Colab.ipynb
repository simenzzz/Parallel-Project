# %% [markdown]
# # Parallel 3D Voxelization - CUDA Backend
#
# This notebook compiles and runs the CUDA parallel implementation of the 3D Voxelization project.

# %%
# 1. Clone the repository
# !git clone https://github.com/simenzzz/Parallel-Project.git
# %cd Parallel-Project

# %%
# 2. Build the targets
# Note: Colab GPUs usually support sm_75 (T4) or higher
# !make clean
# !make CUDA_ARCH=sm_75 all

# %%
# 3. Run the full benchmark matrix
# This will run Seq, OMP, Pthreads, MPI, and CUDA across all meshes and resolutions
# !python3 scripts/bench.py

# %%
# 4. Identify the results
# The benchmark script creates a timestamped folder in results/
# !ls -d results/run_*

# %% [markdown]
# ### Next Steps:
# 1. In the Colab file browser, navigate to the `results/run_YYYYMMDD_HHMMSS/` folder.
# 2. Download the `cuda.csv` file.
# 3. Move it to your local machine into your latest results folder to combine it with CPU results.
